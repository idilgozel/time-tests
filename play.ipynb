# %%
import times as times

# %%
range1= times.time_range('2010-01-12 10:38:00', '2010-01-12 10:45:00')
range2= times.time_range('2002-01-12 10:40:00', '2002-01-12 10:50:00')

# %%
times.compute_overlap_time(range1, range2)
# Out:
# [('2010-01-12 10:38:00', '2002-01-12 10:50:00')]
